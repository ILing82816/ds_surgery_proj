# %% [markdown]
# # SHAP

# %%
import shap
lgb_explainer = shap.TreeExplainer(lgb_gbmhy)
# Out:
# Setting feature_perturbation = "tree_path_dependent" because no background data was given.

# %%
lgb_shap_vals_train=lgb_explainer.shap_values(x_train)
# Out:
# LightGBM binary classifier with TreeExplainer shap values output has changed to a list of ndarray

# %%
lgb_shap_vals_test=lgb_explainer.shap_values(x_val)

# %%
shap.summary_plot(lgb_shap_vals_train, x_train)

# %%
shap.summary_plot(lgb_shap_vals_test, x_val)

# %% [markdown]
# ## Depand on the above two plot, we can see the "SCHED_SURG_PROC CD" is the most important variable to impact the prediction.

# %% [markdown]
# ## If there are different surgery area, it have different surgery code. Depand on surgery area, the risk of surgery have different. Therefore, there are different the risk of a "long" length of stay post-surgery.
